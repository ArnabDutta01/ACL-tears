# %%
import pydicom

ds = pydicom.dcmread("IM-1211-0001-0002.dcm")

print(ds.StudyInstanceUID)
print(ds.SeriesInstanceUID)
print(ds.InstanceNumber)
# Out:
# 1.2.826.0.1.3680043.8.437.1.2.2.1.15712.1675239815.10779
# 1.3.46.670589.11.83031.5.0.2536.2023020119103943000
# 1

# %%
ds = pydicom.dcmread("IM-1211-0001-0002.dcm")

print(ds.StudyInstanceUID)
print(ds.SeriesInstanceUID)
print(ds.InstanceNumber)
# Out:
# 1.2.826.0.1.3680043.8.437.1.2.2.1.15712.1675239815.10779
# 1.3.46.670589.11.83031.5.0.10436.2023020119110589994
# 1
