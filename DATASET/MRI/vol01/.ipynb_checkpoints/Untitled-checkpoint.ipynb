# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt

# %%
with open("329637-8.pck", "rb") as f:
    data = pickle.load(f)

# %%
type(data)
# Out:
# numpy.ndarray

# %%
print(data.shape)
print(data.dtype)
# Out:
# (32, 320, 320)
# uint16

# %%
plt.imshow(data[0], cmap="gray")
plt.title("First MRI Slice")
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(319.5), np.float64(319.5), np.float64(-0.5))

# %%
plt.imshow(data[10], cmap="gray")
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(319.5), np.float64(319.5), np.float64(-0.5))

# %%
import numpy as np

print("Shape:", 329637-8.pck.shape)
print("Data type:", mri.dtype)
print("Min value:", mri.min())
print("Max value:", mri.max())
# Out:
# -----------------------------------------------------------------
# NameError                       Traceback (most recent call last)
# Cell In[7], line 3
#       1 import numpy as np
# ----> 3 print("Shape:", mri.shape)
#       4 print("Data type:", mri.dtype)
#       5 print("Min value:", mri.min())
#
# NameError: name 'mri' is not defined
