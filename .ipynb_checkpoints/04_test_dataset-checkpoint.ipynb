# %%
import pandas as pd
from dataset import KneeDataset

df = pd.read_csv(r"C:\ML projects\ACL tears\DATASET\metadata.csv")

data_dir = r"C:\ML projects\ACL tears\DATASET"

dataset = KneeDataset(df, data_dir)

# %%
print(len(dataset))
# Out:
# 917

# %%
x, y = dataset[0]

print("Input shape:", x.shape)
print("Label:", y)
# Out:
# Input shape: torch.Size([1, 8, 128, 128])
# Label: tensor(0.)
