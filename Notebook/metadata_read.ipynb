# %%
import pandas as pd

# Replace with your actual file path
file_path = r"C:\ML projects\ACL tears\DATASET\combined\metadata.csv"

df = pd.read_csv(file_path)

# %%
df
# Out:
#                      patient_id                        filename  label  \
# 0                150 NORMAL ACL              150_NORMAL_ACL.npz      0
# 1                199 NORMAL ACL              199_NORMAL_ACL.npz      0
# 2    214 NORMAL ACL BONE BRUISE  214_NORMAL_ACL_BONE_BRUISE.npz      0
# 3                219 NORMAL ACL              219_NORMAL_ACL.npz      0
# 4       225 NORMAL ACL MENISCUS     225_NORMAL_ACL_MENISCUS.npz      0
# ..                          ...                             ...    ...
# 461      448 1 ACL BONE BRUISE      448_1_ACL_BONE_BRUISE.npz      1
# 462             462 POST OP ACL             462_POST_OP_ACL.npz      1
# 463       463 1 ACL BONE BRUISE       463_1_ACL_BONE_BRUISE.npz      1
# 464             471 POST OP ACL             471_POST_OP_ACL.npz      1
# 465             483 POST OP ACL             483_POST_OP_ACL.npz      1
#
#     label_name  num_slices  height  width          series
# ...

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

df
# Out:
#                               patient_id  \
# 0                         150 NORMAL ACL
# 1                         199 NORMAL ACL
# 2             214 NORMAL ACL BONE BRUISE
# 3                         219 NORMAL ACL
# 4                225 NORMAL ACL MENISCUS
# 5                         226 NORMAL ACL
# 6                         251 NORMAL ACL
# 7             259 NORMAL ACL BONE BRUISE
# 8                267 NORMAL ACL MENISCUS
# 9                         268 NORMAL ACL
# 10                        303 NORMAL ACL
# 11                        317 NORMAL ACL
# 12            356 NORMAL ACL BONE BRUISE
# 13                        358 NORMAL ACL
# 14                        360 NORMAL ACL
# 15                        364 NORMAL ACL
# 16                        377 NORMAL ACL
# 17                        378 NORMAL ACL
# 18            399 NORMAL ACL BONE BRUISE
# 19                        414 NORMAL ACL
# 20                        418 NORMAL ACL
# 21            423 NORMAL ACL BONE BRUISE
# ...
